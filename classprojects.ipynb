# %% [markdown]
# #### Name : Daniel Obere
# #### Matric No: 211

# %% [markdown]
# ![project1.png](attachment:project1.png)

# %% [markdown]
# #### input number
# #### if number>17 return 2 * magnitude(difference between 2 numbers)
# #### else return difference

# %%
number=float(input("Enter in a number"))
if number>17:
    print(2*abs((17-float(number)))
    
else:
    print(float(number)-17)
# Out:
# Enter in a number18
# 1.0

# %%
number1=float(input("Enter the first number:  "))
number2=float(input("Enter the second number:  "))
number3= float(input("Enter the third number "))
if number1 == number2 and number2==number3 and number1==number3:
    print(3*(number1 + number2 + number3))
else:
    print(number1 + number2 + number3)
# Out:
# Enter the first number:  3
# Enter the second number:  3
# Enter the third number 3
# 27.0

# %% [markdown]
# ## INPUT first number
# ## INPUT second number
# ## INPUT third number
# ## if three numbers are equal print 3(first number * second number * third number)
# ## else sum= first second and third numbers
# ## PRINT sum

# %%
a=float(input("Enter the first number: "))
b= float(input("Enter the second number: "))
if abs(a-b)==5 or a==b or a+b ==5:
    print(True)
else:
    print(False)
# Out:
# Enter the first number: 2
# Enter the second number: 2
# True

# %% [markdown]
# ##### INPUT first number
# ###### INPUT second number
# ##### if tjeir difference or sum is eaual to 5 or the two numbers are equal
# ##### Print True
# ##### else print false

# %% [markdown]
# #### INPUT first number
# #### INPUT second number
# #### INPUT third number
# ####  ARRANGE the three numbers in ascending order
# #### PRINT smallest number
# #### PRINT middle number
# #### PRINT largest number

# %%
n1=int(input("Enter number: "))
n2= int(input("Enter second number: "))
n3= int(input("Enter third number:   "))
list=[n1,n2,n3]
list.sort()
a=list[0]
b=list[1]
c=list[2]
print("The smallest number is", a)
print("The middle number is ",b)
print("The biggest number is ", c)
# Out:
# Enter number: 24
# Enter second number: 12
# Enter third number:   10
# The smallest number is 10
# The middle number is  12
# The biggest number is  24

# %% [markdown]
# #### for element in sumlist
# #### sum(sumlist)

# %%
sumlist=[]
number=int(input("Enter a number"))
while number > 1:
    number -=1
    cube=(number**3)
    print(cube)
    sumlist.append(cube)
    print(sum (sumlist))
# Out:
# Enter a number5
# 64
# 64
# 27
# 91
# 8
# 99
# 1
# 100

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)
